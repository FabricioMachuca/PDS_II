# %% [markdown]
# # LECTURA DE IMAGÉNES CON OPENCV

# %% [markdown]
# *LIBRERÍAS*

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# *Obtención de imagen*

# %%
img = cv2.imread('C:/Users/FABRICIO/Pictures/fondos/OIP.jpg')

# %%
cv2.imshow('imagen',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# *Tamaño de la imagen*

# %%
print(img.shape)
# Out:
# (474, 474, 3)

# %%
rgb_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)   #invierte colores
plt.subplot(2,1,1)
plt.imshow(img)
plt.subplot(2,1,2)
plt.imshow(rgb_img)
plt.show()

# %%
gray_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)   #escala de grises
plt.subplot(2,1,1)
plt.imshow(img)
plt.subplot(2,1,2)
plt.imshow(gray_img)
plt.show()

# %%
azul, verde, rojo = cv2.split(img)
cv2.imshow('Original',img)
cv2.imshow('Azul',azul)
cv2.imshow('Verde',verde)
cv2.imshow('Rojo',rojo)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 azul, verde, rojo = cv2.split(img)
#       2 cv2.imshow('Original',img)
#       3 cv2.imshow('Azul',azul)
#
# NameError: name 'cv2' is not defined
