# %% [markdown]
# # TRANSFORMACIONES ELEMENTALES

# %% [markdown]
# _Librerías_

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# _LECTURA DE IMAGEN_

# %%
img = cv2.imread('C:/Users/FABRICIO/Pictures/fondos/186244.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(2,1,1)
plt.imshow(img)
plt.show()

# %% [markdown]
# # Operador Identidad

# %%
import cv2
import numpy as np

img = cv2.imread('C:/Users/FABRICIO/Pictures/fondos/186244.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)             #correción de colores para libreria matplotlib
imgG = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
imgO= np.zeros(img.shape,np.uint8)
rows = imgG.shape[0]
cols = imgG.shape[1]

# Recorrido de píxeles
for j in range(rows):
    for i in range(cols):
            imgO[j,i]=imgG[j,i]

# Visualizar la imagen suavizada con filtro
titles = ['Imagen Original', 'Operador Identidad']
images = [img, imgO]

plt.figure(figsize=(10, 5))

for i in range(2):
    plt.subplot(1, 2, i+1)
    plt.imshow(images[i])
    plt.title(titles[i])
    plt.axis('off')

plt.show()

# %% [markdown]
# # Operador Inverso

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

#img = cv2.imread('C:/Users/FABRICIO/Pictures/fondos/186244.jpg')
imgG = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
imgO= np.zeros(img.shape,np.uint8)
rows = imgG.shape[0]
cols = imgG.shape[1]

for j in range(rows):
    for i in range(cols):
        imgO[j,i]=255-imgG[j,i]

# Visualizar la imagen suavizada con filtro
titles = ['Imagen Original', 'Operador Inverso']
images = [img, imgO]

plt.figure(figsize=(10, 5))

for i in range(2):
    plt.subplot(1, 2, i+1)
    plt.imshow(images[i])
    plt.title(titles[i])
    plt.axis('off')

plt.show()

# %% [markdown]
# # Binarización

# %% [markdown]
# _Primera manera_

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

#img = cv2.imread('C:/Users/FABRICIO/Pictures/186244.jpg')
#imgG = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
print(imgG.shape[1])
rows = imgG.shape[0]
cols = imgG.shape[1]
#imgO = np.zeros(img.shape, np.uint8)

for j in range(rows):
    for i in range(cols):
        if imgG[j,i]<=90:
            imgO[j,i]=0
        else:
            imgO[j,i]=255

# Visualizar la imagen suavizada con filtro
titles = ['Imagen Original', 'Binarización']
images = [img, imgO]

plt.figure(figsize=(10, 5))

for i in range(2):
    plt.subplot(1, 2, i+1)
    plt.imshow(images[i])
    plt.title(titles[i])
    plt.axis('off')

plt.show()
# Out:
# 1920

# %% [markdown]
# _Segunda manera_

# %%
img = cv2.imread('C:/Users/FABRICIO/Pictures/fondos/186244.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
imgG = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, imgB = cv2.threshold(imgG, 90, 255, cv2.THRESH_BINARY)

titles = ['Imagen Original', 'Binarización']
images = [img, imgO]

plt.figure(figsize=(10, 5))

for i in range(2):
    plt.subplot(1, 2, i+1)
    plt.imshow(images[i])
    plt.title(titles[i])
    plt.axis('off')

plt.show()

# %% [markdown]
# # Binarización Negativa

# %%
#img = cv2.imread('C:/Users/FABRICIO/Pictures/186244.jpg')
#imgG = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#imgO= np.zeros(img.shape,np.uint8)

for j in range(rows):
    for i in range(cols):
        if imgG[j,i]<=90:
            imgO[j,i]=255
        else:
            imgO[j,i]=0

titles = ['Imagen Original', 'Binarización Negativa']
images = [img, imgO]

plt.figure(figsize=(10, 5))

for i in range(2):
    plt.subplot(1, 2, i+1)
    plt.imshow(images[i])
    plt.title(titles[i])
    plt.axis('off')

plt.show()

# %% [markdown]
# # Operador Intervalo de Umbral Binario

# %%
import cv2
import numpy as np

#img = cv2.imread('C:/Users/FABRICIO/Pictures/fondos/186244.jpg')
imgG = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
imgO= np.zeros(img.shape,np.uint8)
rows = imgG.shape[0]
cols = imgG.shape[1]

for j in range(rows):
    for i in range(cols):
        if imgG[j,i]<=100 or imgG[j,i]>=200:
            imgO[j,i]=255
        else:
            imgO[j,i]=0

titles = ['Imagen Original', 'Intervalo de Umbral Binario']
images = [img, imgO]

plt.figure(figsize=(10, 5))

for i in range(2):
    plt.subplot(1, 2, i+1)
    plt.imshow(images[i])
    plt.title(titles[i])
    plt.axis('off')

plt.show()

# %% [markdown]
# #  Operador Intervalo de Umbral Binario Invertido

# %%
import cv2
import numpy as np

#img = cv2.imread('C:/Users/FABRICIO/Pictures/fondos/186244.jpg')
imgG = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
imgO= np.zeros(img.shape,np.uint8)
rows = imgG.shape[0]
cols = imgG.shape[1]

for j in range(rows):
    for i in range(cols):
        if imgG[j,i]<=100 or imgG[j,i]>=200:
            imgO[j,i]=0
        else:
            imgO[j,i]=255

titles = ['Imagen Original', 'Intervalo de Umbral Binario Invertido']
images = [img, imgO]

plt.figure(figsize=(10, 5))

for i in range(2):
    plt.subplot(1, 2, i+1)
    plt.imshow(images[i])
    plt.title(titles[i])
    plt.axis('off')

plt.show()

# %% [markdown]
# # Operador Umbral de escala de grises

# %%
import cv2
import numpy as np

#img = cv2.imread('C:/Users/FABRICIO/Pictures/fondos/186244.jpg')
imgG = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
imgO= np.zeros(img.shape,np.uint8)

for j in range(rows):
    for i in range(cols):
        if imgG[j,i]<=100 or imgG[j,i]>=200:
            imgO[j,i]=255
        else:
            imgO[j,i]=imgG[j,i]

titles = ['Imagen Original', 'Umbral de Escala de Grises']
images = [img, imgO]

plt.figure(figsize=(10, 5))

for i in range(2):
    plt.subplot(1, 2, i+1)
    plt.imshow(images[i])
    plt.title(titles[i])
    plt.axis('off')

plt.show()

# %% [markdown]
# # Operador Umbral de escala de grises inverso

# %%
import cv2
import numpy as np

#img = cv2.imread('C:/Users/FABRICIO/Pictures/fondos/186244.jpg')
imgG = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
imgO= np.zeros(img.shape,np.uint8)

for j in range(rows):
    for i in range(cols):
        if imgG[j,i]<=100 or imgG[j,i]>=200:
            imgO[j,i]=255
        else:
            imgO[j,i]=255-imgG[j,i]

titles = ['Imagen Original', 'Umbral de Escala de Grises Invertido']
images = [img, imgO]

plt.figure(figsize=(10, 5))

for i in range(2):
    plt.subplot(1, 2, i+1)
    plt.imshow(images[i])
    plt.title(titles[i])
    plt.axis('off')

plt.show()

# %% [markdown]
# # Operador de Extension

# %%
import cv2
import numpy as np

#Valores de escala de píxeles
p1=100
p2=200

#img = cv2.imread('C:/Users/FABRICIO/Pictures/fondos/186244.jpg')
imgG = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
imgO= np.zeros(img.shape,np.uint8)
rows = imgG.shape[0]
cols = imgG.shape[1]

for j in range(rows):
    for i in range(cols):
        if imgG[j,i]<=p1 or imgG[j,i]>=p2:
            imgO[j,i]=0
        else:
            num = 255/(p2-p1)
            imgO[j,i]=imgG[j,i]-p1
            prod = [num * i for i in imgO[j,i]] #producto
            imgO[j,i] = prod

titles = ['Imagen Original', 'Operador de Extensión']
images = [img, imgO]

plt.figure(figsize=(10, 5))

for i in range(2):
    plt.subplot(1, 2, i+1)
    plt.imshow(images[i])
    plt.title(titles[i])
    plt.axis('off')

plt.show()

# %% [markdown]
# # BIBLIOGRAFÍA
#
# GONZALO PAJARES, JESÚS M. DE LA CRUZ, JOSE M. MOLINA, JUAN
# CUADRADO, ALEJANDRO LÓPEZ., Imágenes Digitales, 1era Edición, Alfaomega
# grupo Editor. México, 2004.
